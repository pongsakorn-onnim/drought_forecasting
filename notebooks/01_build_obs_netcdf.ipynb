# %%
import sys
import pandas as pd
import numpy as np
import xarray as xr         # มันคือ pandas สำหรับข้อมูล 3 มิติ เช่น NetCDF (Time, Lat, Long)
import rioxarray            # ส่วนเสริมที่ทำให้ xarray เข้าใจไฟล์ภาพ GeoTIFF
from tqdm import tqdm
from pathlib import Path    
from collections import defaultdict

ROOT_PATH = Path.cwd().parent
if ROOT_PATH not in sys.path:
    sys.path.append(str(ROOT_PATH)) 
    
DATA_PATH = ROOT_PATH / "data" 
RAIN_OBS = DATA_PATH / "raw" / "rain_obs_monthly"
PROCESSED_DATA_PATH = DATA_PATH / "processed" 

RAIN_OBS.mkdir(parents=True, exist_ok=True)
PROCESSED_DATA_PATH.mkdir(parents=True, exist_ok=True)

# %%
# 1. เตรียม Dictionary {"yyyymm": Path("...")} เช่น {"197001": "Path("o_th197001.tif"), ..."}
# 2. กวาดหาไฟล์
# 3. คัดเลือกไฟล์
# 4. ส่งออก output

rain_files = RAIN_OBS.glob("o_th*.tif")
rain_dict = {}

for p in rain_files:
        month_key = p.stem.replace("_fixed", "")\
            
        is_fixed = "_fixed" in p.stem
        
        if month_key not in rain_dict:
            rain_dict[month_key] = p
        elif is_fixed:
            rain_dict[month_key] = p
    
rain_paths = sorted(list(rain_dict.values()))

rain_paths[-6:-1]
# Out:
# [WindowsPath('d:/HII/drought_forecasting/data/raw/rain_obs_monthly/o_th202507.tif'),
#  WindowsPath('d:/HII/drought_forecasting/data/raw/rain_obs_monthly/o_th202508.tif'),
#  WindowsPath('d:/HII/drought_forecasting/data/raw/rain_obs_monthly/o_th202509.tif'),
#  WindowsPath('d:/HII/drought_forecasting/data/raw/rain_obs_monthly/o_th202510.tif'),
#  WindowsPath('d:/HII/drought_forecasting/data/raw/rain_obs_monthly/o_th202511.tif')]

# %%
rain_da_list = []    # da ย่อมาจาก DataArray (xarray.DataArray)

for path in tqdm(rain_paths):
    dt = pd.to_datetime(path.stem[4:10], format="%Y%m")

    # masked=True เปลี่ยนค่า nodata ให้เป็น NaN
    with rioxarray.open_rasterio(path, masked=True, chunks="auto") as rain_file:
        da = rain_file.squeeze(dim="band", drop=True).expand_dims(time=[dt])
        
        da.name = "precipitation"
        rain_da_list.append(da)

combined_rain_da = xr.concat(rain_da_list, dim='time', join='override')    # rain_ds ย่อมาจาก Dataset (xaray.Dataset)

# ล้าง Attributes ที่ไม่จำเป็นทิ้ง
keys_to_remove = ['STATISTICS_MAXIMUM', 'STATISTICS_MINIMUM', 
                  'STATISTICS_MEAN', 'STATISTICS_STDDEV']

for key in keys_to_remove:
    if key in combined_rain_da.attrs:
        del combined_rain_da.attrs[key]

rain_ds = combined_rain_da.to_dataset()
# Out:
# 100%|██████████| 672/672 [00:05<00:00, 112.65it/s]

# %%
rain_ds
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:        (time: 672, x: 829, y: 1485)
# Coordinates:
#   * time           (time) datetime64[us] 5kB 1970-01-01 ... 2025-12-01
#   * x              (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#   * y              (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#     spatial_ref    int64 8B 0
# Data variables:
#     precipitation  (time, y, x) float32 3GB dask.array<chunksize=(1, 1485, 829), meta=np.ndarray>

# %%
rain_da_list
# Out:
# [<xarray.DataArray 'precipitation' (time: 1, y: 1485, x: 829)> Size: 5MB
#  dask.array<getitem, shape=(1, 1485, 829), dtype=float32, chunksize=(1, 1485, 829), chunktype=numpy.ndarray>
#  Coordinates:
#    * time         (time) datetime64[us] 8B 1970
.0,
#  <xarray.DataArray 'precipitation' (time: 1, y: 1485, x: 829)> Size: 5MB
#  dask.array<getitem, shape=(1, 1485, 829), dtype=float32, chunksize=(1, 1485, 829), chunktype=numpy.ndarray>
#  Coordinates:
#    * time         (time) datetime64[us] 8B 2025-03-01
#    * y            (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#    * x            (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#      spatial_ref  int64 8B 0
#  Attributes:
#      AREA_OR_POINT:       Area
#      STATISTICS_MAXIMUM:  271.29998779297
#      STATISTICS_MEAN:     -9999
#      STATISTICS_MINIMUM:  0
#      STATISTICS_STDDEV:   -9999
#      scale_factor:        1.0
#      add_offset:          0.0,
#  <xarray.DataArray 'precipitation' (time: 1, y: 1485, x: 829)> Size: 5MB
#  dask.array<getitem, shape=(1, 1485, 829), dtype=float32, chunksize=(1, 1485, 829), chunktype=numpy.ndarray>
#  Coordinates:
#    * time         (time) datetime64[us] 8B 2025-04-01
#    * y            (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#    * x            (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#      spatial_ref  int64 8B 0
#  Attributes:
#      AREA_OR_POINT:       Area
#      STATISTICS_MAXIMUM:  310.55999755859
#      STATISTICS_MEAN:     -9999
#      STATISTICS_MINIMUM:  0.0099999997764826
#      STATISTICS_STDDEV:   -9999
#      scale_factor:        1.0
#      add_offset:          0.0,
#  <xarray.DataArray 'precipitation' (time: 1, y: 1485, x: 829)> Size: 5MB
#  dask.array<getitem, shape=(1, 1485, 829), dtype=float32, chunksize=(1, 1485, 829), chunktype=numpy.ndarray>
#  Coordinates:
#    * time         (time) datetime64[us] 8B 2025-05-01
#    * y            (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#    * x            (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#      spatial_ref  int64 8B 0
#  Attributes:
#      AREA_OR_POINT:           Area
#      STATISTICS_COVARIANCES:  5626.989226108395
#      STATISTICS_MAXIMUM:      808.47998046875
#      STATISTICS_MEAN:         253.47606201176
#      STATISTICS_MINIMUM:      51.419998168945
#      STATISTICS_SKIPFACTORX:  1
#      STATISTICS_SKIPFACTORY:  1
#      STATISTICS_STDDEV:       75.013260335146
#      scale_factor:            1.0
#      add_offset:              0.0,
#  <xarray.DataArray 'precipitation' (time: 1, y: 1485, x: 829)> Size: 5MB
#  dask.array<getitem, shape=(1, 1485, 829), dtype=float32, chunksize=(1, 1485, 829), chunktype=numpy.ndarray>
#  Coordinates:
#    * time         (time) datetime64[us] 8B 2025-06-01
#    * y            (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#    * x            (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#      spatial_ref  int64 8B 0
#  Attributes:
#      AREA_OR_POINT:       Area
#      STATISTICS_MAXIMUM:  1024.5999755859
#      STATISTICS_MEAN:     -9999
#      STATISTICS_MINIMUM:  10.010000228882
#      STATISTICS_STDDEV:   -9999
#      scale_factor:        1.0
#      add_offset:          0.0,
#  <xarray.DataArray 'precipitation' (time: 1, y: 1485, x: 829)> Size: 5MB
#  dask.array<getitem, shape=(1, 1485, 829), dtype=float32, chunksize=(1, 1485, 829), chunktype=numpy.ndarray>
#  Coordinates:
#    * time         (time) datetime64[us] 8B 2025-07-01
#    * y            (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#    * x            (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#      spatial_ref  int64 8B 0
#  Attributes:
#      AREA_OR_POINT:       Area
#      STATISTICS_MAXIMUM:  898.20001220703
#      STATISTICS_MEAN:     -9999
#      STATISTICS_MINIMUM:  11.430000305176
#      STATISTICS_STDDEV:   -9999
#      scale_factor:        1.0
#      add_offset:          0.0,
#  <xarray.DataArray 'precipitation' (time: 1, y: 1485, x: 829)> Size: 5MB
#  dask.array<getitem, shape=(1, 1485, 829), dtype=float32, chunksize=(1, 1485, 829), chunktype=numpy.ndarray>
#  Coordinates:
#    * time         (time) datetime64[us] 8B 2025-08-01
#    * y            (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#    * x            (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#      spatial_ref  int64 8B 0
#  Attributes:
#      AREA_OR_POINT:       Area
#      STATISTICS_MAXIMUM:  1424.4000244141
#      STATISTICS_MEAN:     -9999
#      STATISTICS_MINIMUM:  42.209999084473
#      STATISTICS_STDDEV:   -9999
#      scale_factor:        1.0
#      add_offset:          0.0,
#  <xarray.DataArray 'precipitation' (time: 1, y: 1485, x: 829)> Size: 5MB
#  dask.array<getitem, shape=(1, 1485, 829), dtype=float32, chunksize=(1, 1485, 829), chunktype=numpy.ndarray>
#  Coordinates:
#    * time         (time) datetime64[us] 8B 2025-09-01
#    * y            (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#    * x            (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#      spatial_ref  int64 8B 0
#  Attributes:
#      AREA_OR_POINT:       Area
#      STATISTICS_MAXIMUM:  953.21002197266
#      STATISTICS_MEAN:     -9999
#      STATISTICS_MINIMUM:  44.639999389648
#      STATISTICS_STDDEV:   -9999
#      scale_factor:        1.0
#      add_offset:          0.0,
#  <xarray.DataArray 'precipitation' (time: 1, y: 1485, x: 829)> Size: 5MB
#  dask.array<getitem, shape=(1, 1485, 829), dtype=float32, chunksize=(1, 1485, 829), chunktype=numpy.ndarray>
#  Coordinates:
#    * time         (time) datetime64[us] 8B 2025-10-01
#    * y            (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#    * x            (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#      spatial_ref  int64 8B 0
#  Attributes:
#      AREA_OR_POINT:       Area
#      STATISTICS_MAXIMUM:  671.44000244141
#      STATISTICS_MEAN:     -9999
#      STATISTICS_MINIMUM:  26.549999237061
#      STATISTICS_STDDEV:   -9999
#      scale_factor:        1.0
#      add_offset:          0.0,
#  <xarray.DataArray 'precipitation' (time: 1, y: 1485, x: 829)> Size: 5MB
#  dask.array<getitem, shape=(1, 1485, 829), dtype=float32, chunksize=(1, 1485, 829), chunktype=numpy.ndarray>
#  Coordinates:
#    * time         (time) datetime64[us] 8B 2025-11-01
#    * y            (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#    * x            (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#      spatial_ref  int64 8B 0
#  Attributes:
#      AREA_OR_POINT:       Area
#      STATISTICS_MAXIMUM:  1647.7800292969
#      STATISTICS_MEAN:     -9999
#      STATISTICS_MINIMUM:  4
#      STATISTICS_STDDEV:   -9999
#      scale_factor:        1.0
#      add_offset:          0.0,
#  <xarray.DataArray 'precipitation' (time: 1, y: 1485, x: 829)> Size: 5MB
#  dask.array<getitem, shape=(1, 1485, 829), dtype=float32, chunksize=(1, 1485, 829), chunktype=numpy.ndarray>
#  Coordinates:
#    * time         (time) datetime64[us] 8B 2025-12-01
#    * y            (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#    * x            (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#      spatial_ref  int64 8B 0
#  Attributes:
#      AREA_OR_POINT:             Area
#      STATISTICS_MAXIMUM:        389.98999023438
#      STATISTICS_MEAN:           23.610920970028
#      STATISTICS_MINIMUM:        0
#      STATISTICS_STDDEV:         55.389749473163
#      STATISTICS_VALID_PERCENT:  35.36
#      scale_factor:              1.0
#      add_offset:                0.0]

# %%
temp = rioxarray.open_rasterio(rain_paths[0])
temp  # หรือ print(temp)
# Out:
# <xarray.DataArray (band: 1, y: 1485, x: 829)> Size: 5MB
# [1231065 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 8B 1
#   * y            (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#   * x            (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:       Area
#     STATISTICS_MAXIMUM:  387.69
#     STATISTICS_MEAN:     24.478840240287
#     STATISTICS_MINIMUM:  0
#     STATISTICS_STDDEV:   55.386335528189
#     _FillValue:          -3.4e+38
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
import dask
print(f"Dask Version: {dask.__version__}")
# Out:
# Dask Version: 2026.1.2

# %%
temp.dims
# Out:
# ('band', 'y', 'x')

# %%
temp2 = temp.squeeze(dim="band")
temp2
# Out:
# <xarray.DataArray (y: 1485, x: 829)> Size: 5MB
# [1231065 values with dtype=float32]
# Coordinates:
#   * y            (y) float64 12kB 20.46 20.45 20.44 20.43 ... 5.64 5.63 5.62
#   * x            (x) float64 7kB 97.35 97.36 97.37 97.38 ... 105.6 105.6 105.6
#     band         int64 8B 1
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:       Area
#     STATISTICS_MAXIMUM:  387.69
#     STATISTICS_MEAN:     24.478840240287
#     STATISTICS_MINIMUM:  0
#     STATISTICS_STDDEV:   55.386335528189
#     _FillValue:          -3.4e+38
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
temp2.dims
# Out:
# ('y', 'x')
