# %%
import sys
print(sys.path)
# Out:
# ['C:\\Users\\cws12345\\anaconda3\\python312.zip', 'C:\\Users\\cws12345\\anaconda3\\DLLs', 'C:\\Users\\cws12345\\anaconda3\\Lib', 'C:\\Users\\cws12345\\anaconda3', 'd:\\HII\\drought_forecasting\\.venv', '', 'd:\\HII\\drought_forecasting\\.venv\\Lib\\site-packages']

# %%
from pathlib import Path
print(Path.cwd())
# Out:
# d:\HII\drought_forecasting\notebooks

# %%
import sys
from pathlib import Path

# ถอยกลับไปที่ Root directory เพื่อให้เรียกไฟล์จาก src/ โฟลเดอร์ได้
project_root = Path.cwd().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.utils.raster_qc import run_qc, assert_qc_passed

raw_dir = project_root / "data/raw/rain_obs_monthly"

res = run_qc(
    folder=raw_dir,
    pattern="o_th*.tif",
    baseline_month=None,
    do_quick_stats=True,
)

print("--- สรุปช่วงเวลา ---")
display(res["df_range"].head())

print("\n--- สถิติข้อมูล (หาค่าติดลบ) ---")
display(res["df_stats"].head())

# hard gate (ตั้ง allow_missing_months ตามที่คุณต้องการ)
assert_qc_passed(
    df_incons=res["df_incons"],
    df_selection_anom=res["df_selection_anom"],
    df_missing=res["df_missing"],
    allow_missing_months=False,
)
# Out:
# --- สรุปช่วงเวลา ---
#   min_month max_month  n_months_detected  n_months_expected_between_min_max  \
# 0    197001    202512                665                                672
#
#    n_missing
# 0          7
# --- สถิติข้อมูล (หาค่าติดลบ) ---
#   month_key        filename  pct_zero  pct_nodata_or_nan        min  \
# 0    197001  o_th197001.tif  4.345872          64.761081   0.000000
# 1    197002  o_th197002.tif  0.021438          64.761081   0.000000
# 2    197003  o_th197003.tif  0.000231          64.761081   0.000000
# 3    197004  o_th197004.tif  0.000000          64.761081   5.010000
# 4    197005  o_th197005.tif  0.000000          64.761081  47.200001
#
#           max    n_total
# 0  387.690002  1231065.0
# 1  165.089996  1231065.0
# 2  198.380005  1231065.0
# 3  273.730011  1231065.0
# 4  510.250000  1231065.0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 28
#      25 display(res["df_stats"].head())
#      27 # hard gate (ตั้ง allow_missing_months ตามที่คุณต้องการ)
# ---> 28 assert_qc_passed(
#      29     df_incons=res["df_incons"],
#      30     df_selection_anom=res["df_selection_anom"],
#      31     df_missing=res["df_missing"],
#      32     allow_missing_months=False,
#      33 )
#
# File d:\HII\drought_forecasting\src\utils\raster_qc.py:1183, in assert_qc_passed(df_incons, df_selection_anom, df_missing, allow_missing_months)
#    1181 if problems:
#    1182     msg = "QC FAILED:\n- " + "\n- ".join(problems)
# -> 1183     raise AssertionError(msg)
#
# AssertionError: QC FAILED:
# - Inconsistent grid/metadata found: 1218 diffs
# - Missing months between min/max: 7 months
