# %%
"""
หน้าที่หลัก:

1. โหลดไฟล์ rain_monthly_clean.nc (โหลดวิเดียวเสร็จ เพราะเป็น Binary)

2. คำนวณ Rolling Sum (3 เดือน, 6 เดือน)

3. เข้าสูตร Gamma Distribution เพื่อแปลงเป็น SPI

4. Save Output: บันทึกเป็น spi_30y.nc (นี่คือ Feature ที่พร้อมเข้า Model ML)
"""
